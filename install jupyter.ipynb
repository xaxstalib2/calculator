# %%
import pandas as pd

# Creating a sample dataset
data = {
    'Product': ['Laptop', 'Smartphone', 'Headphones', 'Monitor', 'Keyboard'],
    'Price': [1200, 800, 150, 300, 50],
    'Stock': [15, 30, 50, 20, 100]
}

# Converting to a DataFrame
df = pd.DataFrame(data)

# Display the data
print(df)


import matplotlib.pyplot as plt

# Creating a scatter plot
plt.figure(figsize=(8, 5))
plt.scatter(df['Stock'], df['Price'], color='blue', marker='o')

# Adding labels and title
plt.title('Product Price vs Stock Quantity')
plt.xlabel('Stock Quantity')
plt.ylabel('Price ($)')

# Displaying the plot
plt.grid(True)
plt.show()
# Out:
#       Product  Price  Stock
# 0      Laptop   1200     15
# 1  Smartphone    800     30
# 2  Headphones    150     50
# 3     Monitor    300     20
# 4    Keyboard     50    100
